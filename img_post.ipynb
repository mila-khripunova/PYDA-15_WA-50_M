# %%
import base64
import requests
import os
import json

    
for file in os.listdir('/Users/mila1/Desktop/в мусор/1'):
    with open('/Users/mila1/Desktop/в мусор/1/'+file, "rb") as file_:
        url = 'https://api.imgbb.com/1/upload'
        payload = {
            "key": ,
            "image": base64.b64encode(file_.read()),
            "name":file
        }
        res = requests.post(url, payload)
dd = json.loads(res.text)['data']['url']

dd
# Out:
# 'https://ibb.co/rQqKbsd'

# %%
import base64
import requests
import io

with open('/Users/mila1/Downloads/907450_site_5300x3533_img_pl71174-21_2.jpg','rb') as file:
    url = "https://api.imgbb.com/1/upload"
    image_read = file.read()
    image_64_encode = base64.encodebytes(image_read)
    payload = {
        "key": ,
        "image": image_64_encode
    }
    res = requests.post(url, payload)
    file.close()
    
res.text
# Out:
# '{"data":{"id":"ck2sF2t","title":"5828caa85e01","url_viewer":"https:\\/\\/ibb.co\\/ck2sF2t","url":"https:\\/\\/i.ibb.co\\/4K40T4M\\/5828caa85e01.jpg","display_url":"https:\\/\\/i.ibb.co\\/hL2TW2H\\/5828caa85e01.jpg","size":435035,"time":"1608146905","expiration":"0","image":{"filename":"5828caa85e01.jpg","name":"5828caa85e01","mime":"image\\/jpeg","extension":"jpg","url":"https:\\/\\/i.ibb.co\\/4K40T4M\\/5828caa85e01.jpg"},"thumb":{"filename":"5828caa85e01.jpg","name":"5828caa85e01","mime":"image\\/jpeg","extension":"jpg","url":"https:\\/\\/i.ibb.co\\/ck2sF2t\\/5828caa85e01.jpg"},"medium":{"filename":"5828caa85e01.jpg","name":"5828caa85e01","mime":"image\\/jpeg","extension":"jpg","url":"https:\\/\\/i.ibb.co\\/hL2TW2H\\/5828caa85e01.jpg"},"delete_url":"https:\\/\\/ibb.co\\/ck2sF2t\\/04886bfce4a388ae44517438801ac0db"},"success":true,"status":200}'

# %%
import base64
import requests
import io

with open('/Users/mila1/Downloads/907450_site_5300x3533_img_pl71174-21_2.jpg','rb') as file:
    url = "https://api.imgbb.com/1/upload"
    image_read = file.read()
base64.encodebytes(image_read)
# Out:
# b'
# ...

# %%
import os
import requests
import cloudinary
import cloudinary.uploader
import cloudinary.api

d='7'

f = open('results_cloudinary'+d+'.txt', 'w')
f.write('Артикул,url,public_id,asset_id\n')
cloudinary.config(
  cloud_name = 'lkhripunova',  
  api_key = ,  
  api_secret = 
)

for file in os.listdir('/Users/mila1/Desktop/161220/'+d):
    try:
        a =  cloudinary.uploader.upload('/Users/mila1/Desktop/161220/'+d+'/'+file,
                           folder = "palitra/",
                           type = 'private')
        f.write(a['original_filename']+','+a['url']+','+a['public_id']+','+a['asset_id']+'\n')
    except:
        print(file)
f.close()
