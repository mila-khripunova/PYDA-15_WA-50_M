# %% [markdown]
# # Домашнее задание к лекции "Настройка среды и работа с GIT"

# %% [markdown]
# ## Задание 1

# %% [markdown]
# ![113318.png](attachment:113318.png)

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-28%20%D0%B2%2014.45.56.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-28%20%D0%B2%2014.45.56.png)

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-28%20%D0%B2%2014.45.24.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-28%20%D0%B2%2014.45.24.png)

# %% [markdown]
# ## Задание 3

# %% [markdown]
# https://github.com/mila-khripunova/PYDA-15_WA-50_M.git

# %% [markdown]
# ## Задание 4 (необязательное)

# %% [markdown]
# Не могла устоять перед грасотой графики GitUp

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-28%20%D0%B2%2015.12.17.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-28%20%D0%B2%2015.12.17.png)
